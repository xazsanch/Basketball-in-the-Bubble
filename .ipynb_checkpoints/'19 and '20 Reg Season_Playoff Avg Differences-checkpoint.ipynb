# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import random
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from datetime import datetime, time
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', None)
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (7, 7),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)

# %%
#Regular Season - Points Per 100 Poss
#a box score estimate of the stats per 100 TEAM possessions
p19 = pd.read_csv('Team Ratings - Playoffs.csv')
p19 = p19[p19['Season']==2019]
p19['Team'] = p19['Team'].astype(str)
p19 = p19.drop(['Rk'],axis=1)

# %%
p19['Playoff ORtg'] = rs19['ORtg']
p19
# Out:
#                       Team   G   W  L   W/L%    PW   PL   ORtg   DRtg  NRtg  \
# 16         Toronto Raptors  24  16  8  0.667  16.2  7.8  110.0  104.4   5.6
# 17   Golden State Warriors  22  14  8  0.636  13.3  8.7  115.3  111.9   3.4
# 18         Milwaukee Bucks  15  10  5  0.667  11.4  3.6  111.1  102.5   8.6
# 19  Portland Trail Blazers  16   8  8  0.500   7.3  8.7  110.6  112.0  -1.4
# 20          Denver Nuggets  14   7  7  0.500   7.8  6.2  114.4  112.5   1.9
# ..                     ...  ..  .. ..    ...   ...  ...    ...    ...   ...
# 27   Oklahoma City Thunder   5   1  4  0.200   1.6  3.4  105.4  111.2  -5.8
# 28           Orlando Magic   5   1  4  0.200   0.6  4.4   96.2  111.2 -15.0
# 29               Utah Jazz   5   1  4  0.200   1.1  3.9   99.2  108.5  -9.3
# 30         Detroit Pistons   4   0  4  0.000   0.2  3.8   96.8  120.2 -23.4
# 31          Indiana Pacers   4   0  4  0.000   1.0  3.0   96.3  104.2  -7.9
#
#      Pace    FTr   3PAr    TS%  Season  Playoff ORtg
# 16   96.0  0.275  0.406  0.561    2019           NaN
# 17   98.1  0.282  0.380  0.589    2019           NaN
# 18  100.1  0.317  0.431  0.560    2019           NaN
# 19   96.0  0.274  0.363  0.541    2019           NaN
# 20   92.6  0.279  0.308  0.538    2019           NaN
# ..    ...    ...    ...    ...     ...           ...
# 27   99.9  0.295  0.365  0.541    2019           NaN
# 28   95.7  0.267  0.419  0.496    2019           NaN
# 29   98.6  0.296  0.414  0.501    2019           NaN
# 30  101.3  0.171  0.344  0.471    2019         113.8
# 31   95.3  0.246  0.356  0.496    2019         115.9
#
# [16 rows x 16 columns]

# %%
rs19 = pd.read_csv('Team Ratings - Reg Season.csv')
rs19 = rs19[rs19['Season']==2019]
rs19 = rs19.drop(['Rk'],axis=1)
rs19['Team'] = rs19['Team'].apply(lambda x: x.split("*")[0])
rs19['Team'] = rs19['Team'].astype(str)
rs19
# Out:
#                      Team   Age   W   L   ORtg   DRtg  NRtg   Pace    FTr  \
# 30        Milwaukee Bucks  26.9  60  22  113.8  105.2   8.6  103.3  0.255
# 31  Golden State Warriors  28.4  57  25  115.9  109.5   6.4  100.9  0.227
# 32        Toronto Raptors  27.3  58  24  113.1  107.1   6.0  100.2  0.247
# 33              Utah Jazz  27.3  50  32  110.9  105.7   5.2  100.3  0.295
# 34        Houston Rockets  29.2  53  29  115.5  110.7   4.8   97.9  0.279
# ..                    ...   ...  ..  ..    ...    ...   ...    ...    ...
# 55          Atlanta Hawks  25.1  29  53  108.1  113.9  -5.8  103.9  0.255
# 56          Chicago Bulls  24.0  22  60  104.8  113.2  -8.4   99.0  0.235
# 57           Phoenix Suns  24.0  19  63  105.9  115.1  -9.2  100.5  0.259
# 58        New York Knicks  23.4  17  65  104.5  113.7  -9.2   99.6  0.270
# 59    Cleveland Cavaliers  25.2  19  63  107.7  117.6  -9.9   96.6  0.236
#
#      3PAr    TS%  Season
# 30  0.419  0.583    2019
# 31  0.384  0.596    2019
# 32  0.379  0.579    2019
# 33  0.394  0.572    2019
# 34  0.519  0.581    2019
# ..    ...    ...     ...
# 55  0.403  0.555    2019
# 56  0.295  0.541    2019
# 57  0.335  0.552    2019
# 58  0.334  0.529    2019
# 59  0.332  0.540    2019
#
# [30 rows x 12 columns]

# %%
labels = ['ORtg','DRtg']
x=np.arange(len(labels))
width=0.35

ortg = [round(np.mean(rs19['ORtg']),2), round(np.mean(rs20['ORtg']),2)]
drtg = [round(np.mean(rs19['DRtg']),2), round(np.mean(rs20['DRtg']),2)]


fig, ax = plt.subplots(figsize=(7,7))

rects1 = ax.bar(x-width/2,ortg, width, color='tab:blue',label='2019')
rects2 = ax.bar(x+width/2,drtg, width, color='tab:orange',label='2020')

ax.set_ylabel('Average Points')
ax.set_title('Average Points in the Post-Season')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='lower right')

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)



fig.tight_layout()
plt.show()

# %%
p20 = pd.read_csv('Team Ratings - Playoffs.csv')
p20 = p20[p20['Season']==2020]
p20 = p20.drop(['Rk'],axis=1)
p20
# Out:
#                       Team   G   W   L   W/L%    PW    PL   ORtg   DRtg  NRtg  \
# 0       Los Angeles Lakers  21  16   5  0.762  14.8   6.2  115.9  108.9   7.0
# 1               Miami Heat  21  14   7  0.667  11.8   9.2  113.5  111.5   2.0
# 2           Boston Celtics  17  10   7  0.588  11.2   5.8  111.3  106.3   5.0
# 3           Denver Nuggets  19   9  10  0.474   8.1  10.9  113.6  116.0  -2.4
# 4     Los Angeles Clippers  13   7   6  0.538   8.2   4.8  115.4  111.1   4.3
# ..                     ...  ..  ..  ..    ...   ...   ...    ...    ...   ...
# 11           Orlando Magic   5   1   4  0.200   1.2   3.8  102.5  111.3  -8.8
# 12  Portland Trail Blazers   5   1   4  0.200   1.0   4.0  104.6  115.0 -10.4
# 13           Brooklyn Nets   4   0   4  0.000   0.3   3.7  102.2  122.0 -19.8
# 14          Indiana Pacers   4   0   4  0.000   0.8   3.2  104.2  115.1 -10.9
# 15      Philadelphia 76ers   4   0   4  0.000   0.7   3.3  105.5  117.9 -12.4
#
#      Pace    FTr   3PAr    TS%  Season
# 0    97.3  0.293  0.407  0.595    2020
# 1    95.9  0.322  0.433  0.587    2020
# 2    96.4  0.285  0.429  0.572    2020
# 3    94.1  0.260  0.392  0.584    2020
# 4    98.0  0.291  0.380  0.585    2020
# ..    ...    ...    ...    ...     ...
# 11  104.4  0.237  0.449  0.547    2020
# 12  101.9  0.283  0.347  0.537    2020
# 13  103.5  0.268  0.504  0.518    2020
# 14   96.7  0.252  0.399  0.565    2020
# 15   95.2  0.381  0.360  0.512    2020
#
# [16 rows x 15 columns]

# %%
rs20 = pd.read_csv('Team Ratings - Reg Season.csv')
rs20 = rs20[rs20['Season']==2020]
rs20 = rs20.drop(['Rk'],axis=1)
rs20['Team'] = rs20['Team'].apply(lambda x: x.split("*")[0])
rs20['Team'] = rs20['Team'].astype(str)
rs20
